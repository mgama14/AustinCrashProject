# %% [markdown]
# ### Austin Crash Data Extract Script

# %%
# 📦 Importing libraries
import requests
import pandas as pd
import json
import os
import io
from azure.storage.blob import BlobServiceClient
from time import sleep

# 🔐 Load config from config.json
def load_config(config_path="config.json"):
    with open(config_path, "r", encoding="utf-8") as config_file:
        config = json.load(config_file)
    return config["AZURE_CONNECTION_STRING"], config["austin_container"]

AZURE_CONNECTION_STRING, CONTAINER_NAME = load_config()

# 🌐 API Setup
API_ENDPOINT = "https://data.austintexas.gov/resource/y2wy-tgr5.json"
LIMIT = 1000

def fetch_all_data():
    all_records = []
    offset = 0

    while True:
        print(f"📥 Fetching rows {offset} to {offset + LIMIT - 1}")
        response = requests.get(API_ENDPOINT, params={"$limit": LIMIT, "$offset": offset})
        response.raise_for_status()
        batch = response.json()

        if not batch:
            break  # No more data

        all_records.extend(batch)
        offset += LIMIT
        sleep(0.2)  # Rate limit protection

    print(f"✅ Total records retrieved: {len(all_records)}")
    return all_records

# 🧼 Fetch and convert to CSV string
records = fetch_all_data()
df = pd.DataFrame(records)
csv_string = df.to_csv(index=False)

# ☁️ Upload to Azure Blob Storage
def upload_to_azure(csv_text, blob_name):
    blob_service_client = BlobServiceClient.from_connection_string(AZURE_CONNECTION_STRING)
    container_client = blob_service_client.get_container_client(CONTAINER_NAME)

    try:
        container_client.create_container()
        print(f"📦 Created container: {CONTAINER_NAME}")
    except Exception as e:
        print(f"⚠️ Container might already exist: {e}")

    print(f"☁️ Uploading to Azure Blob: {blob_name}")
    csv_bytes = io.BytesIO(csv_text.encode("utf-8"))
    container_client.upload_blob(name=blob_name, data=csv_bytes, overwrite=True)
    print("✅ Upload complete!")

# 🧾 Final upload call
upload_to_azure(csv_string, "austincrashdatafull.csv".strip())
# Out:
# 📥 Fetching rows 0 to 999
# 📥 Fetching rows 1000 to 1999
# 📥 Fetching rows 2000 to 2999
# 📥 Fetching rows 3000 to 3999
# 📥 Fetching rows 4000 to 4999
# 📥 Fetching rows 5000 to 5999
# 📥 Fetching rows 6000 to 6999
# 📥 Fetching rows 7000 to 7999
# 📥 Fetching rows 8000 to 8999
# 📥 Fetching rows 9000 to 9999
# 📥 Fetching rows 10000 to 10999
# 📥 Fetching rows 11000 to 11999
# 📥 Fetching rows 12000 to 12999
# 📥 Fetching rows 13000 to 13999
# 📥 Fetching rows 14000 to 14999
# 📥 Fetching rows 15000 to 15999
# 📥 Fetching rows 16000 to 16999
# 📥 Fetching rows 17000 to 17999
# 📥 Fetching rows 18000 to 18999
# 📥 Fetching rows 19000 to 19999
# 📥 Fetching rows 20000 to 20999
# 📥 Fetching rows 21000 to 21999
# 📥 Fetching rows 22000 to 22999
# 📥 Fetching rows 23000 to 23999
# 📥 Fetching rows 24000 to 24999
# 📥 Fetching rows 25000 to 25999
# 📥 Fetching rows 26000 to 26999
# 📥 Fetching rows 27000 to 27999
# 📥 Fetching rows 28000 to 28999
# 📥 Fetching rows 29000 to 29999
# 📥 Fetching rows 30000 to 30999
# 📥 Fetching rows 31000 to 31999
# 📥 Fetching rows 32000 to 32999
# 📥 Fetching rows 33000 to 33999
# 📥 Fetching rows 34000 to 34999
# 📥 Fetching rows 35000 to 35999
# 📥 Fetching rows 36000 to 36999
# 📥 Fetching rows 37000 to 37999
# 📥 Fetching rows 38000 to 38999
# 📥 Fetching rows 39000 to 39999
# 📥 Fetching rows 40000 to 40999
# 📥 Fetching rows 41000 to 41999
# 📥 Fetching rows 42000 to 42999
# 📥 Fetching rows 43000 to 43999
# 📥 Fetching rows 44000 to 44999
# 📥 Fetching rows 45000 to 45999
# 📥 Fetching rows 46000 to 46999
# 📥 Fetching rows 47000 to 47999
# 📥 Fetching rows 48000 to 48999
# 📥 Fetching rows 49000 to 49999
# 📥 Fetching rows 50000 to 50999
# 📥 Fetching rows 51000 to 51999
# 📥 Fetching rows 52000 to 52999
# 📥 Fetching rows 53000 to 53999
# 📥 Fetching rows 54000 to 54999
# 📥 Fetching rows 55000 to 55999
# 📥 Fetching rows 56000 to 56999
# 📥 Fetching rows 57000 to 57999
# 📥 Fetching rows 58000 to 58999
# 📥 Fetching rows 59000 to 59999
# 📥 Fetching rows 60000 to 60999
# 📥 Fetching rows 61000 to 61999
# 📥 Fetching rows 62000 to 62999
# 📥 Fetching rows 63000 to 63999
# 📥 Fetching rows 64000 to 64999
# 📥 Fetching rows 65000 to 65999
# 📥 Fetching rows 66000 to 66999
# 📥 Fetching rows 67000 to 67999
# 📥 Fetching rows 68000 to 68999
# 📥 Fetching rows 69000 to 69999
# 📥 Fetching rows 70000 to 70999
# 📥 Fetching rows 71000 to 71999
# 📥 Fetching rows 72000 to 72999
# 📥 Fetching rows 73000 to 73999
# 📥 Fetching rows 74000 to 74999
# 📥 Fetching rows 75000 to 75999
# 📥 Fetching rows 76000 to 76999
# 📥 Fetching rows 77000 to 77999
# 📥 Fetching rows 78000 to 78999
# 📥 Fetching rows 79000 to 79999
# 📥 Fetching rows 80000 to 80999
# 📥 Fetching rows 81000 to 81999
# 📥 Fetching rows 82000 to 82999
# 📥 Fetching rows 83000 to 83999
# 📥 Fetching rows 84000 to 84999
# 📥 Fetching rows 85000 to 85999
# 📥 Fetching rows 86000 to 86999
# 📥 Fetching rows 87000 to 87999
# 📥 Fetching rows 88000 to 88999
# 📥 Fetching rows 89000 to 89999
# 📥 Fetching rows 90000 to 90999
# 📥 Fetching rows 91000 to 91999
# 📥 Fetching rows 92000 to 92999
# 📥 Fetching rows 93000 to 93999
# 📥 Fetching rows 94000 to 94999
# 📥 Fetching rows 95000 to 95999
# 📥 Fetching rows 96000 to 96999
# 📥 Fetching rows 97000 to 97999
# 📥 Fetching rows 98000 to 98999
# 📥 Fetching rows 99000 to 99999
# 📥 Fetching rows 100000 to 100999
# 📥 Fetching rows 101000 to 101999
# 📥 Fetching rows 102000 to 102999
# 📥 Fetching rows 103000 to 103999
# 📥 Fetching rows 104000 to 104999
# 📥 Fetching rows 105000 to 105999
# 📥 Fetching rows 106000 to 106999
# 📥 Fetching rows 107000 to 107999
# 📥 Fetching rows 108000 to 108999
# 📥 Fetching rows 109000 to 109999
# 📥 Fetching rows 110000 to 110999
# 📥 Fetching rows 111000 to 111999
# 📥 Fetching rows 112000 to 112999
# 📥 Fetching rows 113000 to 113999
# 📥 Fetching rows 114000 to 114999
# 📥 Fetching rows 115000 to 115999
# 📥 Fetching rows 116000 to 116999
# 📥 Fetching rows 117000 to 117999
# 📥 Fetching rows 118000 to 118999
# 📥 Fetching rows 119000 to 119999
# 📥 Fetching rows 120000 to 120999
# 📥 Fetching rows 121000 to 121999
# 📥 Fetching rows 122000 to 122999
# 📥 Fetching rows 123000 to 123999
# 📥 Fetching rows 124000 to 124999
# 📥 Fetching rows 125000 to 125999
# 📥 Fetching rows 126000 to 126999
# 📥 Fetching rows 127000 to 127999
# 📥 Fetching rows 128000 to 128999
# 📥 Fetching rows 129000 to 129999
# 📥 Fetching rows 130000 to 130999
# 📥 Fetching rows 131000 to 131999
# 📥 Fetching rows 132000 to 132999
# 📥 Fetching rows 133000 to 133999
# 📥 Fetching rows 134000 to 134999
# 📥 Fetching rows 135000 to 135999
# 📥 Fetching rows 136000 to 136999
# 📥 Fetching rows 137000 to 137999
# 📥 Fetching rows 138000 to 138999
# 📥 Fetching rows 139000 to 139999
# 📥 Fetching rows 140000 to 140999
# 📥 Fetching rows 141000 to 141999
# 📥 Fetching rows 142000 to 142999
# 📥 Fetching rows 143000 to 143999
# 📥 Fetching rows 144000 to 144999
# 📥 Fetching rows 145000 to 145999
# 📥 Fetching rows 146000 to 146999
# 📥 Fetching rows 147000 to 147999
# 📥 Fetching rows 148000 to 148999
# 📥 Fetching rows 149000 to 149999
# 📥 Fetching rows 150000 to 150999
# 📥 Fetching rows 151000 to 151999
# 📥 Fetching rows 152000 to 152999
# 📥 Fetching rows 153000 to 153999
# 📥 Fetching rows 154000 to 154999
# 📥 Fetching rows 155000 to 155999
# 📥 Fetching rows 156000 to 156999
# 📥 Fetching rows 157000 to 157999
# 📥 Fetching rows 158000 to 158999
# 📥 Fetching rows 159000 to 159999
# 📥 Fetching rows 160000 to 160999
# 📥 Fetching rows 161000 to 161999
# 📥 Fetching rows 162000 to 162999
# 📥 Fetching rows 163000 to 163999
# 📥 Fetching rows 164000 to 164999
# 📥 Fetching rows 165000 to 165999
# 📥 Fetching rows 166000 to 166999
# 📥 Fetching rows 167000 to 167999
# 📥 Fetching rows 168000 to 168999
# 📥 Fetching rows 169000 to 169999
# 📥 Fetching rows 170000 to 170999
# 📥 Fetching rows 171000 to 171999
# 📥 Fetching rows 172000 to 172999
# 📥 Fetching rows 173000 to 173999
# 📥 Fetching rows 174000 to 174999
# 📥 Fetching rows 175000 to 175999
# 📥 Fetching rows 176000 to 176999
# 📥 Fetching rows 177000 to 177999
# 📥 Fetching rows 178000 to 178999
# 📥 Fetching rows 179000 to 179999
# 📥 Fetching rows 180000 to 180999
# 📥 Fetching rows 181000 to 181999
# 📥 Fetching rows 182000 to 182999
# 📥 Fetching rows 183000 to 183999
# 📥 Fetching rows 184000 to 184999
# 📥 Fetching rows 185000 to 185999
# 📥 Fetching rows 186000 to 186999
# 📥 Fetching rows 187000 to 187999
# 📥 Fetching rows 188000 to 188999
# 📥 Fetching rows 189000 to 189999
# 📥 Fetching rows 190000 to 190999
# 📥 Fetching rows 191000 to 191999
# 📥 Fetching rows 192000 to 192999
# 📥 Fetching rows 193000 to 193999
# 📥 Fetching rows 194000 to 194999
# 📥 Fetching rows 195000 to 195999
# 📥 Fetching rows 196000 to 196999
# 📥 Fetching rows 197000 to 197999
# 📥 Fetching rows 198000 to 198999
# 📥 Fetching rows 199000 to 199999
# 📥 Fetching rows 200000 to 200999
# 📥 Fetching rows 201000 to 201999
# 📥 Fetching rows 202000 to 202999
# 📥 Fetching rows 203000 to 203999
# 📥 Fetching rows 204000 to 204999
# 📥 Fetching rows 205000 to 205999
# 📥 Fetching rows 206000 to 206999
# 📥 Fetching rows 207000 to 207999
# 📥 Fetching rows 208000 to 208999
# 📥 Fetching rows 209000 to 209999
# 📥 Fetching rows 210000 to 210999
# 📥 Fetching rows 211000 to 211999
# 📥 Fetching rows 212000 to 212999
# 📥 Fetching rows 213000 to 213999
# 📥 Fetching rows 214000 to 214999
# 📥 Fetching rows 215000 to 215999
# 📥 Fetching rows 216000 to 216999
# 📥 Fetching rows 217000 to 217999
# 📥 Fetching rows 218000 to 218999
# ✅ Total records retrieved: 217394
# 📦 Created container: austincrashesraw
# ☁️ Uploading to Azure Blob: austincrashdatafull.csv
# ✅ Upload complete!
